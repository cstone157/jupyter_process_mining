# %%
## Has to be run as root
## $ docker exec -it -u root suspicious_hermann /bin/bash
## # apt-get update
## # apt-get install graphviz

## Installing this results in an error, but if not installed there's a warning.  Don't care, not going to fix
# !pip install pulp
#!pip install pm4py

import datetime
import random

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

import pm4py

# %%
from gen_data import Data_Generator

generator = Data_Generator()
tab_df = generator.gen_tabular_data()
tab_df.head()
# Out:
#       id                                            message  \
# 0   id_0  Message regarding entity [entity_id_0] tracked...
# 1  idx_1  Message regarding entity [entity_idx_1] tracke...
# 2  idx_2  Message regarding entity [entity_idx_2] tracke...
# 3  idx_3  Message regarding entity [entity_idx_3] tracke...
# 4   id_4  Message regarding entity [entity_id_4] tracked...
#
#                       sensed                   transfer  \
# 0 2024-10-22 16:07:15.912309 2024-10-22 16:21:48.912309
# 1 2024-10-22 16:52:09.912309 2024-10-22 16:54:23.912309
# 2 2024-10-22 16:45:45.912309                        NaT
# 3 2024-10-22 16:49:53.912309 2024-10-22 17:10:45.912309
# 4 2024-10-22 15:57:37.912309 2024-10-22 16:10:48.912309
#
#                    submitted                  transfer2
# 0 2024-10-22 16:42:42.912309 2024-10-22 16:44:23.912309
# 1 2024-10-22 17:00:26.912309 2024-10-22 17:01:48.912309
# 2                        NaT                        NaT
# 3 2024-10-22 17:35:10.912309 2024-10-22 17:36:24.912309
# 4 2024-10-22 16:35:28.912309 2024-10-22 16:36:24.912309

# %%
log_df = generator.gen_event_log_data()
log_df.head()
# Out:
#      id                                            message      state  \
# 0  id_0  Message regarding entity [entity_id_0] tracked...     sensed
# 1  id_0  Message regarding entity [entity_id_0] tracked...   transfer
# 2  id_0  Message regarding entity [entity_id_0] tracked...  submitted
# 3  id_0  Message regarding entity [entity_id_0] tracked...  transfer2
# 4     1  Message regarding entity [entity_1] tracked by...     sensed
#
#                    timestamp
# 0 2024-10-22 16:44:29.912309
# 1 2024-10-22 17:00:38.912309
# 2 2024-10-22 17:25:56.912309
# 3 2024-10-22 17:27:30.912309
# 4 2024-10-22 16:22:38.912309
