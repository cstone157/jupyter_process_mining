# %%
## Has to be run as root
## $ docker exec -it -u root suspicious_hermann /bin/bash
## # apt-get update
## # apt-get install graphviz

## Installing this results in an error, but if not installed there's a warning.  Don't care, not going to fix
# !pip install pulp
#!pip install pm4py

import datetime
import random

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

import pm4py

# %%
from gen_data import Data_Generator

generator = Data_Generator()
tab_df = generator.gen_tabular_data()
tab_df.head()
# Out:
#       id                                            message  \
# 0  idx_0  Message regarding entity [entity_id00idx_0] tr...
# 1      1  Message regarding entity [entity_id001] tracke...
# 2  idx_2  Message regarding entity [entity_id00idx_2] tr...
# 3      3  Message regarding entity [entity_id003] tracke...
# 4      4  Message regarding entity [entity_id004] tracke...
#
#                       sensed                   transfer  \
# 0 2024-10-21 20:02:37.179750 2024-10-21 20:27:08.179750
# 1 2024-10-21 20:38:40.179750 2024-10-21 21:00:28.179750
# 2 2024-10-21 20:34:16.179750 2024-10-21 20:45:37.179750
# 3 2024-10-21 20:02:45.179750 2024-10-21 20:15:55.179750
# 4 2024-10-21 20:43:43.179750 2024-10-21 21:04:08.179750
#
#                    submitted                  transfer2
# 0 2024-10-21 20:39:07.179750                        NaT
# 1 2024-10-21 21:13:37.179750 2024-10-21 21:33:57.179750
# 2 2024-10-21 21:02:59.179750 2024-10-21 21:06:10.179750
# 3 2024-10-21 20:27:21.179750 2024-10-21 20:38:21.179750
# 4 2024-10-21 21:17:54.179750 2024-10-21 21:23:58.179750
